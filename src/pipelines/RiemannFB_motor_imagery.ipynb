# %%
# Pipeline riemanniana a banco di filtri con riallineamento per run (run 4, 8, 12).
# Sinistra vs destra immaginata, stessa impalcatura delle altre pipeline per essere
# direttamente confrontabile: stesse run, finestre 2s/0.5s, stessa Leave-One-Run-Out,
# stessa soglia probabilistica, stessi canali. Cambia solo come si estraggono le feature
# e quale classificatore le usa.
#
# Perche' questo approccio e non una rete neurale: per fold ci sono circa 28 trial
# indipendenti. In quel regime una rete addestrata da zero per soggetto non generalizza,
# mentre i metodi basati su covarianza con regolarizzazione a shrinkage sono progettati
# esattamente per il caso "poche osservazioni, molte dimensioni".
# --- Preambolo standard ------------------------------------------------------
import sys
from pathlib import Path

PROJECT_ROOT = next(
    p for p in [Path.cwd(), *Path.cwd().parents]
    if (p / "dataset_description.json").exists()
)
DATA  = PROJECT_ROOT / "data"
PLOTS = PROJECT_ROOT / "src" / "plots"
sys.path.insert(0, str(PROJECT_ROOT / "src"))
# -----------------------------------------------------------------------------

import time
import warnings
import numpy as np
import mne
from mne_bids import BIDSPath, read_raw_bids
from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV, StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
from sklearn.exceptions import ConvergenceWarning
from util.preprocessing import create_sliding_windows, create_window_labels
from util.riemann_filterbank import (
    DEFAULT_BANDS, run_covariances, reference_mean, recenter, to_tangent, n_features
)

warnings.filterwarnings("ignore", category=ConvergenceWarning)
mne.set_log_level('WARNING')

# --- Configurazione ----------------------------------------------------------

root = DATA
runs = ["4", "8", "12"]
test_run_order = [runs[2], runs[1], runs[0]]
first_person = 1
people = 109

window_size = 2         # identici alle altre pipeline, per confrontabilita'
step_size = 0.5
label_threshold = 0.8

# Banda larga: le sotto-bande del banco fanno la selezione fine
L_FREQ = 4
H_FREQ = 40
BANDS = DEFAULT_BANDS   # [(8, 13), (13, 20), (20, 30)]

CHANNELS = ["C3", "C4", "Cz", "Fc3", "Fc4", "Fcz", "Cp3", "Cp4", "Cpz"]

# Riallineamento delle covarianze:
#   "per_run" -> ogni run viene riportata sul proprio baricentro. Il baricentro non usa le
#                etichette, quindi si puo' stimare anche sulla run di test: e' adattamento di
#                dominio non supervisionato. E' la configurazione che ci si aspetta migliore.
#   "train"   -> tutte le run vengono riportate sul baricentro delle sole run di training.
#                Piu' conservativo: nessuna statistica della run di test viene usata.
RECENTER = "per_run"

# Il classificatore e' quasi privo di iperparametri: la LDA con shrinkage di Ledoit-Wolf
# regolarizza da sola ed e' deterministica, a differenza dell'SVM con probability=True le cui
# probabilita' passano da una calibrazione di Platt con mescolamento casuale interno.
# Griglia minuscola: con 28 trial indipendenti cercare fra decine di combinazioni insegue rumore.
param_grid = {
    "clf__shrinkage": ["auto", 0.2, 0.5],
}

START_THRESHOLD = 0.90
MIN_THRESHOLD = 0.50
MIN_ACCEPTED_RATIO = 0.70

# NaN e non 0: un fold che fallisce deve restare fuori dalle medie, non entrarci come 0%
all_accuracy = np.full((people, len(test_run_order)), np.nan)
all_discarded = np.full((people, len(test_run_order)), np.nan)
cm_sum = np.zeros((2, 2))

print(f"Feature per finestra: {n_features(len(CHANNELS), len(BANDS))} "
      f"({len(BANDS)} bande x {len(CHANNELS)} canali)")
print()

# --- Loop principale ---------------------------------------------------------

for i in range(first_person, first_person + people):
    subject = f"{i:03d}"
    subject_start = time.time()

    print("=" * 60)
    print(f"Paziente {subject}")
    print("=" * 60)

    for test_index, test_run in enumerate(test_run_order):
        test_start = time.time()
        train_runs = [run for run in runs if run != test_run]

        # Per ogni run si conservano le covarianze di TUTTE le finestre (servono a stimare il
        # baricentro senza usare le etichette) e la maschera di quelle attive.
        per_run = {}
        trial_offset = 0

        for run in runs:
            bids_path = BIDSPath(
                subject=subject, task="motion", run=run, datatype="eeg", root=root,
            )

            try:
                raw = read_raw_bids(bids_path, verbose=False)
                events, event_id = mne.events_from_annotations(raw, verbose=False)
                raw.load_data(verbose=False)
                raw.filter(l_freq=L_FREQ, h_freq=H_FREQ, verbose=False)
                raw.set_eeg_reference('average', projection=False, verbose=False)

                sfreq = raw.info['sfreq']
                event_map = {
                    event_id['TASK2T0']: 1,
                    event_id['TASK2T1']: 2,
                    event_id['TASK2T2']: 3
                }

                windows, window_samples, step_samples, total_samples = create_sliding_windows(
                    raw, window_size, step_size
                )
                picks = mne.pick_channels(raw.ch_names, CHANNELS)
                windows = windows[:, picks, :]

                y, groups = create_window_labels(
                    events, event_map, total_samples, window_samples, step_samples,
                    threshold=label_threshold, return_groups=True
                )
                groups = np.where(groups >= 0, groups + trial_offset, -1)
                trial_offset += len(events)

                # Covarianze su TUTTE le finestre: il baricentro va stimato sull'intera run,
                # senza guardare quali finestre siano attive ne' di che classe siano.
                covs = run_covariances(windows, sfreq, BANDS)

                mask_active = y != 1
                per_run[run] = {
                    "covs": covs,
                    "mask": mask_active,
                    "y": np.where(y[mask_active] == 2, 0, 1),
                    "groups": groups[mask_active],
                }

            except Exception as e:
                print(f"Errore {subject} run {run}: {e}")

        if not all(r in per_run for r in runs):
            print(f"  Dati insufficienti per la run di test {test_run}")
            continue

        # --- Riallineamento ---------------------------------------------------
        # Se il riferimento e' quello di training, si calcola una volta sola dalle covarianze
        # delle run di training messe insieme; altrimenti ogni run usa il proprio.
        if RECENTER == "train":
            references = [
                reference_mean(np.concatenate([per_run[r]["covs"][b] for r in train_runs]))
                for b in range(len(BANDS))
            ]

        features = {}
        for run in runs:
            aligned = []
            for b in range(len(BANDS)):
                covs_b = per_run[run]["covs"][b]
                ref = references[b] if RECENTER == "train" else reference_mean(covs_b)
                aligned.append(recenter(covs_b, ref))

            # Solo dopo il riallineamento si tengono le finestre attive
            mask = per_run[run]["mask"]
            features[run] = to_tangent([a[mask] for a in aligned])

        X_train = np.concatenate([features[r] for r in train_runs])
        y_train = np.concatenate([per_run[r]["y"] for r in train_runs])
        groups_train = np.concatenate([per_run[r]["groups"] for r in train_runs])

        X_test = features[test_run]
        y_test = per_run[test_run]["y"]

        # --- Classificazione ---------------------------------------------------
        pipe = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", LinearDiscriminantAnalysis(solver="lsqr")),
        ])

        cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
        grid = GridSearchCV(pipe, param_grid, cv=cv,
                            scoring="balanced_accuracy", n_jobs=-1)
        grid.fit(X_train, y_train, groups=groups_train)

        probs = grid.predict_proba(X_test)
        max_probs = np.max(probs, axis=1)
        predictions = np.argmax(probs, axis=1)

        threshold = START_THRESHOLD
        accepted_mask = max_probs >= threshold
        while np.sum(accepted_mask) < MIN_ACCEPTED_RATIO * len(y_test) and threshold > MIN_THRESHOLD:
            threshold -= 0.05
            accepted_mask = max_probs >= threshold

        accepted = int(np.sum(accepted_mask))
        total = len(y_test)
        discarded = total - accepted

        accuracy = balanced_accuracy_score(y_test[accepted_mask], predictions[accepted_mask])
        all_accuracy[i - first_person, test_index] = accuracy
        all_discarded[i - first_person, test_index] = 100 * discarded / total
        cm_sum += confusion_matrix(y_test[accepted_mask], predictions[accepted_mask])

        print(f"  Run test: {test_run} | Threshold: {threshold:.2f} | "
              f"Riallineamento: {RECENTER}")
        print(f"  Campioni: {total} tot / {accepted} accettati / {discarded} scartati "
              f"({100*discarded/total:.1f}%)")
        print(f"  Balanced accuracy sugli accettati: {accuracy*100:.2f}% | "
              f"score interno: {grid.best_score_*100:.2f}% | shrinkage: {grid.best_params_}")
        print(f"  Tempo: {time.time() - test_start:.1f}s\n")

    patient_mean = np.nanmean(all_accuracy[i - first_person])
    patient_discarded = np.nanmean(all_discarded[i - first_person])
    print(f"  Paziente {subject}: {patient_mean*100:.2f}% con {patient_discarded:.1f}% di scarti "
          f"| Tempo: {time.time() - subject_start:.1f}s\n")

# --- Riepilogo ---------------------------------------------------------------

n_folds = int(np.count_nonzero(~np.isnan(all_accuracy)))
n_falliti = all_accuracy.size - n_folds
print("=" * 60)
print(f"Fold riusciti:          {n_folds}/{all_accuracy.size}"
      + (f" ({n_falliti} falliti, esclusi dalle medie)" if n_falliti else ""))
print(f"Accuratezza media:      {np.nanmean(all_accuracy)*100:.2f}%")
print(f"Deviazione standard:    {np.nanstd(all_accuracy)*100:.2f}%")
print(f"Campioni scartati:      {np.nanmean(all_discarded):.1f}% in media")
print(f"Matrice di confusione media:\n{(cm_sum / n_folds).astype(int)}")
# Out:
# Feature per finestra: 135 (3 bande x 9 canali)
#
# ============================================================
# Paziente 001
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 93.89% | score interno: 66.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 16.4s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 66.38% | score interno: 73.61% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 11.6s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 79.88% | score interno: 73.89% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 001: 80.05% con 19.8% di scarti | Tempo: 35.3s
#
# ============================================================
# Paziente 002
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 72 accettati / 12 scartati (14.3%)
#   Balanced accuracy sugli accettati: 77.92% | score interno: 72.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 73 accettati / 11 scartati (13.1%)
#   Balanced accuracy sugli accettati: 83.67% | score interno: 77.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 81.99% | score interno: 67.50% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 002: 81.19% con 18.3% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 003
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 64.93% | score interno: 64.44% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 77.95% | score interno: 50.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 67 accettati / 17 scartati (20.2%)
#   Balanced accuracy sugli accettati: 67.77% | score interno: 63.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 003: 70.22% con 22.6% di scarti | Tempo: 21.9s
#
# ============================================================
# Paziente 004
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 80.09% | score interno: 66.39% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 67 accettati / 17 scartati (20.2%)
#   Balanced accuracy sugli accettati: 74.15% | score interno: 73.61% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 92.08% | score interno: 74.17% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 004: 82.10% con 17.9% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 005
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 52.15% | score interno: 62.50% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.5s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 66.03% | score interno: 53.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 63.21% | score interno: 47.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 005: 60.47% con 23.4% di scarti | Tempo: 22.0s
#
# ============================================================
# Paziente 006
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 49.55% | score interno: 60.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 68.24% | score interno: 51.94% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.75 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 55.43% | score interno: 47.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 006: 57.74% con 27.4% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 007
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 84 accettati / 0 scartati (0.0%)
#   Balanced accuracy sugli accettati: 97.62% | score interno: 87.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.5s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 81 accettati / 3 scartati (3.6%)
#   Balanced accuracy sugli accettati: 90.09% | score interno: 96.11% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 78 accettati / 6 scartati (7.1%)
#   Balanced accuracy sugli accettati: 94.59% | score interno: 93.33% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 007: 94.10% con 3.6% di scarti | Tempo: 22.1s
#
# ============================================================
# Paziente 008
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 69.86% | score interno: 50.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 67 accettati / 17 scartati (20.2%)
#   Balanced accuracy sugli accettati: 44.33% | score interno: 65.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 55.24% | score interno: 62.22% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Paziente 008: 56.48% con 21.0% di scarti | Tempo: 21.3s
#
# ============================================================
# Paziente 009
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 53.08% | score interno: 45.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 53.36% | score interno: 46.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 53.54% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 6.9s
#
#   Paziente 009: 53.33% con 22.2% di scarti | Tempo: 21.0s
#
# ============================================================
# Paziente 010
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 45.94% | score interno: 64.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 50.96% | score interno: 64.17% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 73.30% | score interno: 64.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Paziente 010: 56.74% con 27.4% di scarti | Tempo: 21.0s
#
# ============================================================
# Paziente 011
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 53.69% | score interno: 55.00% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 60.66% | score interno: 49.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 51.22% | score interno: 62.22% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Paziente 011: 55.19% con 27.0% di scarti | Tempo: 21.3s
#
# ============================================================
# Paziente 012
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 83.43% | score interno: 48.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 64.89% | score interno: 57.50% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 74.19% | score interno: 61.11% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 012: 74.17% con 25.4% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 013
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 73 accettati / 11 scartati (13.1%)
#   Balanced accuracy sugli accettati: 73.87% | score interno: 61.11% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 68.92% | score interno: 68.61% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 84.03% | score interno: 55.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 013: 75.61% con 20.2% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 014
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 57.20% | score interno: 60.00% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 56.47% | score interno: 55.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 59.10% | score interno: 56.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 014: 57.59% con 23.0% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 015
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 82.83% | score interno: 67.78% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 77.87% | score interno: 76.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 78.96% | score interno: 75.28% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 015: 79.88% con 25.4% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 016
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 49.76% | score interno: 52.78% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 62.74% | score interno: 67.22% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 72 accettati / 12 scartati (14.3%)
#   Balanced accuracy sugli accettati: 55.56% | score interno: 66.11% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 016: 56.02% con 21.8% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 017
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 42.37% | score interno: 54.44% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 48.77% | score interno: 44.17% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 46.14% | score interno: 37.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 017: 45.76% con 26.6% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 018
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 41.47% | score interno: 41.39% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 39.80% | score interno: 46.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 63.40% | score interno: 38.89% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Paziente 018: 48.23% con 25.0% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 019
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 57.36% | score interno: 65.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 57.62% | score interno: 62.78% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 62.12% | score interno: 58.89% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.4s
#
#   Paziente 019: 59.03% con 21.4% di scarti | Tempo: 21.7s
#
# ============================================================
# Paziente 020
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 49.29% | score interno: 51.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 64.06% | score interno: 38.06% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 41.43% | score interno: 58.33% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 020: 51.60% con 27.4% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 021
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 61.74% | score interno: 57.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 57.68% | score interno: 63.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 55.98% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 021: 58.46% con 26.2% di scarti | Tempo: 22.0s
#
# ============================================================
# Paziente 022
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 44.30% | score interno: 50.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.4s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 36.42% | score interno: 57.50% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 49.02% | score interno: 63.33% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.4s
#
#   Paziente 022: 43.25% con 19.8% di scarti | Tempo: 22.0s
#
# ============================================================
# Paziente 023
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 79.94% | score interno: 63.61% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 64.48% | score interno: 69.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 73 accettati / 11 scartati (13.1%)
#   Balanced accuracy sugli accettati: 74.96% | score interno: 63.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 023: 73.13% con 24.2% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 024
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 72.79% | score interno: 60.28% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 76.46% | score interno: 60.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 61.95% | score interno: 57.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 024: 70.40% con 22.6% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 025
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 70.54% | score interno: 72.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 76.67% | score interno: 63.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 69.27% | score interno: 62.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 025: 72.16% con 23.0% di scarti | Tempo: 21.0s
#
# ============================================================
# Paziente 026
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 73.04% | score interno: 67.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 83.43% | score interno: 55.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 61.55% | score interno: 81.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 026: 72.67% con 24.6% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 027
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 64.02% | score interno: 62.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 61.92% | score interno: 61.39% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 49.20% | score interno: 43.89% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 027: 58.38% con 24.2% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 028
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 45.59% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 52.30% | score interno: 58.33% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 38.10% | score interno: 51.39% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 028: 45.33% con 23.4% di scarti | Tempo: 21.7s
#
# ============================================================
# Paziente 029
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 82 accettati / 2 scartati (2.4%)
#   Balanced accuracy sugli accettati: 97.56% | score interno: 94.17% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.5s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 80 accettati / 4 scartati (4.8%)
#   Balanced accuracy sugli accettati: 96.22% | score interno: 91.39% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 78 accettati / 6 scartati (7.1%)
#   Balanced accuracy sugli accettati: 97.44% | score interno: 95.28% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Paziente 029: 97.07% con 4.8% di scarti | Tempo: 22.3s
#
# ============================================================
# Paziente 030
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 37.50% | score interno: 46.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 32.12% | score interno: 41.11% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 45.98% | score interno: 50.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 030: 38.53% con 23.4% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 031
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 60.29% | score interno: 79.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 77.52% | score interno: 75.83% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 83.91% | score interno: 65.83% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 031: 73.91% con 22.2% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 032
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 72 accettati / 12 scartati (14.3%)
#   Balanced accuracy sugli accettati: 85.45% | score interno: 86.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 76 accettati / 8 scartati (9.5%)
#   Balanced accuracy sugli accettati: 90.82% | score interno: 79.17% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 75.84% | score interno: 85.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.5s
#
#   Paziente 032: 84.04% con 13.1% di scarti | Tempo: 22.0s
#
# ============================================================
# Paziente 033
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 88.39% | score interno: 64.72% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 72 accettati / 12 scartati (14.3%)
#   Balanced accuracy sugli accettati: 49.58% | score interno: 76.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 65.49% | score interno: 68.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 033: 67.82% con 21.8% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 034
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 85.65% | score interno: 75.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 91.18% | score interno: 73.33% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 72.86% | score interno: 86.11% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Paziente 034: 83.23% con 17.1% di scarti | Tempo: 21.7s
#
# ============================================================
# Paziente 035
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 60.27% | score interno: 65.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 57.08% | score interno: 66.67% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 51.01% | score interno: 68.33% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 035: 56.12% con 23.8% di scarti | Tempo: 21.8s
#
# ============================================================
# Paziente 036
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 64.58% | score interno: 43.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.75 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 43.94% | score interno: 58.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 43.64% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Paziente 036: 50.72% con 25.0% di scarti | Tempo: 21.4s
#
# ============================================================
# Paziente 037
# ============================================================
#   Run test: 12 | Threshold: 0.75 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 43.99% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 52.53% | score interno: 48.89% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 41.67% | score interno: 60.28% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Paziente 037: 46.06% con 25.4% di scarti | Tempo: 21.3s
#
# ============================================================
# Paziente 038
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 47.32% | score interno: 37.22% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 36.88% | score interno: 40.56% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 40.69% | score interno: 47.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Paziente 038: 41.63% con 23.4% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 039
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 73 accettati / 11 scartati (13.1%)
#   Balanced accuracy sugli accettati: 43.77% | score interno: 50.56% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 29.73% | score interno: 55.28% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 38.32% | score interno: 44.72% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Paziente 039: 37.27% con 22.6% di scarti | Tempo: 21.7s
#
# ============================================================
# Paziente 040
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 62.35% | score interno: 57.78% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 65.17% | score interno: 45.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 51.79% | score interno: 58.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Paziente 040: 59.77% con 23.8% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 041
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 51.77% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 57.14% | score interno: 61.94% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 45.08% | score interno: 55.83% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Paziente 041: 51.33% con 24.2% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 042
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 77 accettati / 7 scartati (8.3%)
#   Balanced accuracy sugli accettati: 94.44% | score interno: 83.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 82 accettati / 2 scartati (2.4%)
#   Balanced accuracy sugli accettati: 97.56% | score interno: 71.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 77 accettati / 7 scartati (8.3%)
#   Balanced accuracy sugli accettati: 75.44% | score interno: 97.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Paziente 042: 89.15% con 6.3% di scarti | Tempo: 21.9s
#
# ============================================================
# Paziente 043
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 72.54% | score interno: 63.61% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 79 accettati / 5 scartati (6.0%)
#   Balanced accuracy sugli accettati: 76.32% | score interno: 60.28% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 59.00% | score interno: 76.94% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Paziente 043: 69.29% con 11.5% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 044
# ============================================================
#   Run test: 12 | Threshold: 0.75 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 61.52% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 68.71% | score interno: 54.72% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.70 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 62.57% | score interno: 45.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Paziente 044: 64.27% con 28.6% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 045
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 61.32% | score interno: 57.22% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.4s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 66.19% | score interno: 56.39% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.4s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 44.35% | score interno: 58.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 11.4s
#
#   Paziente 045: 57.29% con 23.4% di scarti | Tempo: 26.2s
#
# ============================================================
# Paziente 046
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 74 accettati / 10 scartati (11.9%)
#   Balanced accuracy sugli accettati: 61.92% | score interno: 63.33% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 10.5s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 70.27% | score interno: 52.78% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 10.0s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 71.47% | score interno: 58.89% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 10.2s
#
#   Paziente 046: 67.88% con 22.6% di scarti | Tempo: 30.7s
#
# ============================================================
# Paziente 047
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 54.69% | score interno: 65.83% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.9s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 44.96% | score interno: 54.17% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 10.0s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 52.94% | score interno: 72.78% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 9.8s
#
#   Paziente 047: 50.86% con 24.6% di scarti | Tempo: 29.7s
#
# ============================================================
# Paziente 048
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 72.93% | score interno: 78.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 10.2s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 70.20% | score interno: 61.94% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.8s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 68.75% | score interno: 59.72% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.8s
#
#   Paziente 048: 70.63% con 24.2% di scarti | Tempo: 29.7s
#
# ============================================================
# Paziente 049
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 69 accettati / 15 scartati (17.9%)
#   Balanced accuracy sugli accettati: 81.22% | score interno: 70.28% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.6s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 77.74% | score interno: 68.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.7s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 67.50% | score interno: 78.89% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 8.4s
#
#   Paziente 049: 75.49% con 18.3% di scarti | Tempo: 27.7s
#
# ============================================================
# Paziente 050
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 50.28% | score interno: 64.17% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 9.6s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 55.90% | score interno: 50.83% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 9.6s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 48.33% | score interno: 65.83% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 9.6s
#
#   Paziente 050: 51.50% con 26.6% di scarti | Tempo: 28.8s
#
# ============================================================
# Paziente 051
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 45.63% | score interno: 48.89% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 10.5s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 50.64% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 10.5s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 48.88% | score interno: 48.89% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 10.4s
#
#   Paziente 051: 48.38% con 28.2% di scarti | Tempo: 31.4s
#
# ============================================================
# Paziente 052
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 72 accettati / 12 scartati (14.3%)
#   Balanced accuracy sugli accettati: 65.28% | score interno: 78.89% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 11.6s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 71.24% | score interno: 70.83% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 11.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 93.38% | score interno: 58.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 11.4s
#
#   Paziente 052: 76.63% con 23.4% di scarti | Tempo: 34.1s
#
# ============================================================
# Paziente 053
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 70.97% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 10.7s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 78.59% | score interno: 61.39% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 10.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 64.06% | score interno: 76.11% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 10.6s
#
#   Paziente 053: 71.21% con 19.8% di scarti | Tempo: 31.7s
#
# ============================================================
# Paziente 054
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 73 accettati / 11 scartati (13.1%)
# ...
#   Balanced accuracy sugli accettati: 57.64% | score interno: 60.73% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 5.6s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 144 tot / 109 accettati / 35 scartati (24.3%)
#   Balanced accuracy sugli accettati: 58.60% | score interno: 56.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 5.7s
#
#   Paziente 092: 57.81% con 26.9% di scarti | Tempo: 16.8s
#
# ============================================================
# Paziente 093
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 77.73% | score interno: 71.67% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 69.33% | score interno: 75.83% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 73.05% | score interno: 73.06% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 093: 73.37% con 21.4% di scarti | Tempo: 21.3s
#
# ============================================================
# Paziente 094
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 78 accettati / 6 scartati (7.1%)
#   Balanced accuracy sugli accettati: 88.22% | score interno: 88.61% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 75 accettati / 9 scartati (10.7%)
#   Balanced accuracy sugli accettati: 94.67% | score interno: 87.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 77 accettati / 7 scartati (8.3%)
#   Balanced accuracy sugli accettati: 88.34% | score interno: 93.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 6.9s
#
#   Paziente 094: 90.41% con 8.7% di scarti | Tempo: 21.0s
#
# ============================================================
# Paziente 095
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 60.25% | score interno: 55.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 65.44% | score interno: 60.00% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 63.87% | score interno: 64.17% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 095: 63.18% con 19.4% di scarti | Tempo: 21.6s
#
# ============================================================
# Paziente 096
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 55.04% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 55.78% | score interno: 61.94% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 41.41% | score interno: 62.78% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Paziente 096: 50.75% con 24.2% di scarti | Tempo: 21.3s
#
# ============================================================
# Paziente 097
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 70.00% | score interno: 56.67% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.5s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 50.81% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 54.41% | score interno: 54.72% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 6.9s
#
#   Paziente 097: 58.41% con 27.4% di scarti | Tempo: 21.5s
#
# ============================================================
# Paziente 098
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 67 accettati / 17 scartati (20.2%)
#   Balanced accuracy sugli accettati: 42.01% | score interno: 66.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 48.85% | score interno: 58.89% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 6.9s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 66.09% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 098: 52.32% con 24.2% di scarti | Tempo: 21.0s
#
# ============================================================
# Paziente 099
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 42.71% | score interno: 61.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 6.7s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 71 accettati / 13 scartati (15.5%)
#   Balanced accuracy sugli accettati: 57.05% | score interno: 71.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 68.74% | score interno: 63.33% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 6.9s
#
#   Paziente 099: 56.17% con 19.0% di scarti | Tempo: 20.8s
#
# ============================================================
# Paziente 100
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 88 tot / 72 accettati / 16 scartati (18.2%)
#   Balanced accuracy sugli accettati: 45.75% | score interno: 50.83% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 5.7s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 88 tot / 62 accettati / 26 scartati (29.5%)
#   Balanced accuracy sugli accettati: 13.87% | score interno: 62.29% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 5.7s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 88 tot / 63 accettati / 25 scartati (28.4%)
#   Balanced accuracy sugli accettati: 43.20% | score interno: 52.71% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 5.4s
#
#   Paziente 100: 34.27% con 25.4% di scarti | Tempo: 16.9s
#
# ============================================================
# Paziente 101
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 60 accettati / 24 scartati (28.6%)
#   Balanced accuracy sugli accettati: 47.14% | score interno: 55.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 50.48% | score interno: 54.44% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 34.85% | score interno: 42.78% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Paziente 101: 44.15% con 23.0% di scarti | Tempo: 21.1s
#
# ============================================================
# Paziente 102
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 65 accettati / 19 scartati (22.6%)
#   Balanced accuracy sugli accettati: 78.96% | score interno: 74.17% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 66.32% | score interno: 64.17% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 64 accettati / 20 scartati (23.8%)
#   Balanced accuracy sugli accettati: 77.39% | score interno: 66.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 6.8s
#
#   Paziente 102: 74.22% con 21.8% di scarti | Tempo: 20.8s
#
# ============================================================
# Paziente 103
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 54.69% | score interno: 63.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 62.63% | score interno: 65.00% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 77.76% | score interno: 59.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Paziente 103: 65.02% con 25.8% di scarti | Tempo: 21.2s
#
# ============================================================
# Paziente 104
# ============================================================
#   Run test: 12 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 57.02% | score interno: 61.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 6.8s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 72 tot / 51 accettati / 21 scartati (29.2%)
#   Balanced accuracy sugli accettati: 61.80% | score interno: 54.44% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 39.35% | score interno: 68.89% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 6.8s
#
#   Paziente 104: 52.72% con 26.4% di scarti | Tempo: 20.7s
#
# ============================================================
# Paziente 105
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 71.00% | score interno: 68.06% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 6.9s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 73.73% | score interno: 58.61% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 55.07% | score interno: 71.39% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.0s
#
#   Paziente 105: 66.60% con 23.4% di scarti | Tempo: 21.1s
#
# ============================================================
# Paziente 106
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 68 accettati / 16 scartati (19.0%)
#   Balanced accuracy sugli accettati: 52.01% | score interno: 51.94% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 59 accettati / 25 scartati (29.8%)
#   Balanced accuracy sugli accettati: 49.12% | score interno: 52.50% | shrinkage: {'clf__shrinkage': 0.2}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 38.04% | score interno: 58.61% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 106: 46.39% con 25.4% di scarti | Tempo: 21.7s
#
# ============================================================
# Paziente 107
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 61 accettati / 23 scartati (27.4%)
#   Balanced accuracy sugli accettati: 58.76% | score interno: 53.89% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.5s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 45.45% | score interno: 54.17% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.2s
#
#   Run test: 4 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 50.65% | score interno: 49.44% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.1s
#
#   Paziente 107: 51.62% con 23.4% di scarti | Tempo: 21.8s
#
# ============================================================
# Paziente 108
# ============================================================
#   Run test: 12 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 66 accettati / 18 scartati (21.4%)
#   Balanced accuracy sugli accettati: 86.31% | score interno: 82.50% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 8 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 70 accettati / 14 scartati (16.7%)
#   Balanced accuracy sugli accettati: 91.43% | score interno: 81.67% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.3s
#
#   Run test: 4 | Threshold: 0.90 | Riallineamento: per_run
#   Campioni: 84 tot / 74 accettati / 10 scartati (11.9%)
#   Balanced accuracy sugli accettati: 89.30% | score interno: 75.56% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.2s
#
#   Paziente 108: 89.01% con 16.7% di scarti | Tempo: 21.8s
#
# ============================================================
# Paziente 109
# ============================================================
#   Run test: 12 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 40.00% | score interno: 50.56% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Run test: 8 | Threshold: 0.85 | Riallineamento: per_run
#   Campioni: 84 tot / 62 accettati / 22 scartati (26.2%)
#   Balanced accuracy sugli accettati: 58.06% | score interno: 42.22% | shrinkage: {'clf__shrinkage': 'auto'}
#   Tempo: 7.0s
#
#   Run test: 4 | Threshold: 0.80 | Riallineamento: per_run
#   Campioni: 84 tot / 63 accettati / 21 scartati (25.0%)
#   Balanced accuracy sugli accettati: 44.85% | score interno: 41.11% | shrinkage: {'clf__shrinkage': 0.5}
#   Tempo: 7.0s
#
#   Paziente 109: 47.64% con 25.4% di scarti | Tempo: 20.9s
#
# ============================================================
# Fold riusciti:          327/327
# Accuratezza media:      62.55%
# Deviazione standard:    16.05%
# Campioni scartati:      22.1% in media
# Matrice di confusione media:
# [[21 12]
#  [12 20]]
